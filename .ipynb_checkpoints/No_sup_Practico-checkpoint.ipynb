# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
from sklearn.preprocessing import StandardScaler
from sklearn_pandas import DataFrameMapper

# %%
url = r"C:\Users\ernes\OneDrive\Escritorio\Carpetas\Repo-git-Ernest\DataScienceRepo\Career Mode player datasets - FIFA 15-22.xlsx"

# %%
df = pd.read_excel(url,sheet_name=7)

# %%
df.body_type.value_counts()
# Out:
# Normal (170-185)    6685
# Normal (185+)       4236
# Lean (170-185)      4086
# Lean (185+)         1938
# Normal (170-)        669
# Stocky (170-185)     560
# Lean (170-)          477
# Stocky (185+)        355
# Unique               136
# Stocky (170-)         97
# Name: body_type, dtype: int64

# %%
df.head(3)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
#
#    overall  potential    value_eur  wage_eur  age        dob  height_cm  \
# 0       93         93   78000000.0  320000.0   34 1987-06-24        170
# 1       92         92  119500000.0  270000.0   32 1988-08-21        185
# 2       91         91   45000000.0  270000.0   36 1985-02-05        187
#
#    weight_kg  club_team_id            club_name             league_name  \
# ...

# %%
pd.set_option('max_rows', 110)
total = df.isnull().sum().sort_values(ascending = False)
percent = (df.isnull().sum() / df.isnull().count()).sort_values(ascending = False)
missing_data = pd.concat([total, percent], axis = 1, keys = ['Total', 'Percent'])
missing_data.head(110)
# Out:
#                              Total   Percent
# nation_logo_url              18480  0.960549
# nation_team_id               18480  0.960549
# nation_position              18480  0.960549
# nation_jersey_number         18480  0.960549
# club_loaned_from             18137  0.942721
# player_tags                  17798  0.925100
# goalkeeping_speed            17107  0.889183
# player_traits                 9841  0.511513
# passing                       2132  0.110817
# shooting                      2132  0.110817
# pace                          2132  0.110817
# defending                     2132  0.110817
# dribbling                     2132  0.110817
# physic                        2132  0.110817
# release_clause_eur            1176  0.061126
# club_joined                   1163  0.060450
# rw                             326  0.016945
# lw                             326  0.016945
# value_eur                       74  0.003846
# club_contract_valid_until       61  0.003171
# ...

# %% [markdown]
# ### Seleccion y eliminacion de columnas

# %% [markdown]
# Columnas que tienen mas del 50% de nulos

# %%
df_drop = df.drop(columns=['nation_logo_url', 'nation_team_id','nation_position','nation_jersey_number','club_loaned_from',
                          'player_tags','goalkeeping_speed','player_traits'])

# %%
pd.set_option('max_rows', 110)
total = df_drop.isnull().sum().sort_values(ascending = False)
percent = (df_drop.isnull().sum() / df_drop.isnull().count()).sort_values(ascending = False)
missing_data = pd.concat([total, percent], axis = 1, keys = ['Total', 'Percent'])
missing_data.head(110)
# Out:
#                              Total   Percent
# pace                          2132  0.110817
# dribbling                     2132  0.110817
# shooting                      2132  0.110817
# passing                       2132  0.110817
# physic                        2132  0.110817
# defending                     2132  0.110817
# release_clause_eur            1176  0.061126
# club_joined                   1163  0.060450
# lw                             326  0.016945
# rw                             326  0.016945
# value_eur                       74  0.003846
# club_contract_valid_until       61  0.003171
# club_flag_url                   61  0.003171
# club_jersey_number              61  0.003171
# club_position                   61  0.003171
# wage_eur                        61  0.003171
# league_name                     61  0.003171
# club_name                       61  0.003171
# club_team_id                    61  0.003171
# club_logo_url                   61  0.003171
# ...

# %%
df_drop2 = df_drop.drop(columns=['player_url','short_name','dob','club_jersey_number','club_joined','club_contract_valid_until'
                                ,'nationality_name','international_reputation','real_face','release_clause_eur',
                                'player_face_url','club_logo_url','club_flag_url','nation_flag_url','sofifa_id','player_positions'
                                ,'value_eur','wage_eur'])

# %%
print(df_drop2.shape)
df_drop2.head(3)
# Out:
# (19239, 84)
#                              long_name  overall  potential  age  height_cm  \
# 0       Lionel Andrés Messi Cuccittini       93         93   34        170
# 1                   Robert Lewandowski       92         92   32        185
# 2  Cristiano Ronaldo dos Santos Aveiro       91         91   36        187
#
#    weight_kg  club_team_id            club_name             league_name  \
# 0         72          73.0  Paris Saint-Germain          French Ligue 1
# 1         81          21.0    FC Bayern München    German 1. Bundesliga
# 2         83          11.0    Manchester United  English Premier League
#
#    league_level club_position  nationality_id preferred_foot  weak_foot  \
# 0           1.0            RW              52           Left          4
# 1           1.0            ST              37          Right          4
# 2           1.0            ST              38          Right          4
#
# ...

# %% [markdown]
# ### Tipos de datos

# %%
df_drop2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19239 entries, 0 to 19238
# Data columns (total 84 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   long_name                    19239 non-null  object
#  1   overall                      19239 non-null  int64
#  2   potential                    19239 non-null  int64
#  3   age                          19239 non-null  int64
#  4   height_cm                    19239 non-null  int64
#  5   weight_kg                    19239 non-null  int64
#  6   club_team_id                 19178 non-null  float64
#  7   club_name                    19178 non-null  object
#  8   league_name                  19178 non-null  object
#  9   league_level                 19178 non-null  float64
#  10  club_position                19178 non-null  object
#  11  nationality_id               19239 non-null  int64
#  12  preferred_foot               19239 non-null  object
# ...

# %%
for col in columns1:
    df_drop2[col] = df_drop2[col].replace(np.nan,'0')

# %%
columns1 = ['ls','st','rs','lw','lf','cf','rf','rw','lam','cam','ram','lm',
            'lcm','cm','rcm','rm','lwb','ldm', 'cdm','rdm','rwb','lb','lcb','cb','rcb','rb','gk']
df_drop2[columns1].head()

#for i in columns1:
 #   df_drop2[i]=df_drop2[i].str.split('+',n=1,expand=True)[0]
df_drop2[columns1] = df_drop2[columns1].applymap(lambda x: x.split('+')[0])
# Out:
#        ls  st  rs lw lf cf rf rw lam cam ram  lm lcm  cm rcm  rm lwb ldm cdm  \
# 0      89  89  89  0  0  0  0  0   0   0   0  91  87  87  87  91  66  64  64
# 1      90  90  90  0  0  0  0  0  86  86  86  84  80  80  80  84  64  66  66
# 2      90  90  90  0  0  0  0  0  86  86  86  86  78  78  78  86  63  59  59
# 3      83  83  83  0  0  0  0  0  89  89  89  89  82  82  82  89  67  63  63
# 4      83  83  83  0  0  0  0  0  89  89  89  89  89  89  89  89  79  80  80
# ...    ..  ..  .. .. .. .. .. ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 19234  44  44  44  0  0  0  0  0  46  46  46  47  46  46  46  47  48  46  46
# 19235  45  45  45  0  0  0  0  0  47  47  47  49  47  47  47  49  49  46  46
# 19236  45  45  45  0  0  0  0  0  47  47  47  48  47  47  47  48  47  46  46
# 19237  47  47  47  0  0  0  0  0  45  45  45  45  39  39  39  45  33  29  29
# 19238  45  45  45  0  0  0  0  0  47  47  47  48  46  46  46  48  45  44  44
#
#       rdm rwb  lb lcb  cb rcb  rb  gk
# ...

# %%
df_drop2[columns1] = df_drop2[columns1].applymap(lambda x: x.split('+')[0])
df_drop2[columns1]
# Out:
#        ls  st  rs lw lf cf rf rw lam cam ram  lm lcm  cm rcm  rm lwb ldm cdm  \
# 0      89  89  89  0  0  0  0  0   0   0   0  91  87  87  87  91  66  64  64
# 1      90  90  90  0  0  0  0  0  86  86  86  84  80  80  80  84  64  66  66
# 2      90  90  90  0  0  0  0  0  86  86  86  86  78  78  78  86  63  59  59
# 3      83  83  83  0  0  0  0  0  89  89  89  89  82  82  82  89  67  63  63
# 4      83  83  83  0  0  0  0  0  89  89  89  89  89  89  89  89  79  80  80
# ...    ..  ..  .. .. .. .. .. ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 19234  44  44  44  0  0  0  0  0  46  46  46  47  46  46  46  47  48  46  46
# 19235  45  45  45  0  0  0  0  0  47  47  47  49  47  47  47  49  49  46  46
# 19236  45  45  45  0  0  0  0  0  47  47  47  48  47  47  47  48  47  46  46
# 19237  47  47  47  0  0  0  0  0  45  45  45  45  39  39  39  45  33  29  29
# 19238  45  45  45  0  0  0  0  0  47  47  47  48  46  46  46  48  45  44  44
#
#       rdm rwb  lb lcb  cb rcb  rb  gk
# ...

# %%
for col in columns1:
    df_drop2[col] = df_drop2[col].replace(np.nan,'0')

# %%
for col in columns1:
    df_drop2[col] = df_drop2[col].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13680/1950575961.py in <module>
#       1 for col in columns1:
# ----> 2     df_drop2[col] = df_drop2[col].astype(int)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
# ...
